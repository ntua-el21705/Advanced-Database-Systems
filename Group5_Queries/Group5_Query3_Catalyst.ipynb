# %% [markdown]
# ## QUERY 3: CATALYST OPTIMIZER - HINT & EXPLAIN

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, expr, sum as _sum, avg, round, regexp_replace, trim, format_number

spark = SparkSession.builder \
    .appName("Crime Data Analysis with Median Income") \
    .getOrCreate()

# Load GeoJSON File for 2010 Census Blocks
geojson_path = "s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson"
blocks_df = spark.read.format("geojson") \
    .option("multiLine", "true").load(geojson_path) \
    .selectExpr("explode(features) as features") \
    .select("features.*")

flattened_df = blocks_df.select(
    [col(f"properties.{col_name}").alias(col_name) for col_name in blocks_df.schema["properties"].dataType.fieldNames()] + ["geometry"]
).drop("properties").drop("type")

# Group Polygons per COMM
grouped_blocks_df = flattened_df.groupBy("COMM").agg(
    expr("ST_Union_Aggr(geometry)").alias("unified_geometry")
)

# Load Crime Data
crime_data_path = "s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_Data_from_2010_to_2019_20241101.csv"
crime_df = spark.read.csv(crime_data_path, header=True, inferSchema=True)

crime_df = crime_df.select(
    col("LAT").alias("latitude"),
    col("LON").alias("longitude")
)
crime_df = crime_df.withColumn("geom", expr("ST_Point(longitude, latitude)"))

# Count Crimes per COMM
join_condition = expr("ST_Within(geom, unified_geometry)")
joined_df = crime_df.join(grouped_blocks_df, join_condition, "inner")

# Εμφάνιση του σχεδίου εκτέλεσης για το join
joined_df.explain(True)

crime_counts = joined_df.groupBy("COMM").count()

# Total Population per COMM
community_population_df = flattened_df.groupBy("COMM").agg(
    _sum("POP_2010").alias("total_population")
)

# Total Housing ανά COMM
community_housing_df = flattened_df.groupBy("COMM").agg(
    _sum("HOUSING10").alias("total_housing")
)

# Loan Income Data
income_data = spark.read.option("header", "true").csv("s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv")

# Estimated Median Income Column
income_data = income_data.withColumn(
    "Estimated Median Income", 
    regexp_replace(trim(col("Estimated Median Income")), "[$,]", "").cast("float")
)

# Community Column
income_data = income_data.withColumn(
    "COMM", 
    regexp_replace(col("Community"), "Los Angeles \\(|\\)", "").alias("COMM")
)

# Calculate median income per COMM
median_income_per_comm = income_data.groupBy("COMM").agg(
    round(avg("Estimated Median Income"), 2).alias("median_income")
)

# Join crime_counts, community_population_df, community_housing_df και median_income_per_comm
final_df = crime_counts \
    .join(community_population_df, on="COMM", how="inner") \
    .join(community_housing_df, on="COMM", how="inner") \
    .join(median_income_per_comm, on="COMM", how="left")  # Left join για να διατηρήσουμε περιοχές χωρίς εισόδημα

# Εμφάνιση του σχεδίου εκτέλεσης για το τελικό join
final_df.explain(True)

# Calculate Crime per person
final_df = final_df.withColumn(
    "crimes_per_person", format_number(col("count") / col("total_population"), 5)
)

# Calculate Median Income per Person
final_df = final_df.withColumn(
    "median_income_per_person", 
    round((col("total_housing") * col("median_income")) / col("total_population"), 2)
)

# Filter NULL or empty COMM
final_df = final_df.filter(col("COMM").isNotNull() & (col("COMM") != ""))

# Sort Alphabetically
final_df = final_df.orderBy("COMM")

sorted_columns = sorted(final_df.columns)

final_df.select(sorted_columns).show(n=final_df.count(), truncate=False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# == Parsed Logical Plan ==
# Join Inner,  **org.apache.spark.sql.sedona_sql.expressions.ST_Within**
# :- Project [latitude#877, longitude#878,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#882]
# :  +- Project [LAT#847 AS latitude#877, LON#848 AS longitude#878]
# :     +- Relation [DR_NO#821,Date Rptd#822,DATE OCC#823,TIME OCC#824,AREA #825,AREA NAME#826,Rpt Dist No#827,Part 1-2#828,Crm Cd#829,Crm Cd Desc#830,Mocodes#831,Vict Age#832,Vict Sex#833,Vict Descent#834,Premis Cd#835,Premis Desc#836,Weapon Used Cd#837,Weapon Desc#838,Status#839,Status Desc#840,Crm Cd 1#841,Crm Cd 2#842,Crm Cd 3#843,Crm Cd 4#844,... 4 more fields] csv
# +- Aggregate [COMM#640], [COMM#640, st_union_aggr(geometry#627, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@228b9d6f, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, Some(ST_Union_Aggr)) AS unified_geometry#787]
#    +- Project [properties#628.BG10 AS BG10#633, properties#628.BG10FIP10 AS BG10FIP10#634, properties#628.BG12 AS BG12#635, properties#628.CB10 AS CB10#636, properties#628.CEN_FIP13 AS CEN_FIP13#637, properties#628.CITY AS CITY#638, properties#628.CITYCOM AS CITYCOM#639, properties#628.COMM AS COMM#640, properties#628.CT10 AS CT10#641, properties#628.CT12 AS CT12#642, properties#628.CTCB10 AS CTCB10#643, properties#628.HD_2012 AS HD_2012#644L, properties#628.HD_NAME AS HD_NAME#645, properties#628.HOUSING10 AS HOUSING10#646L, properties#628.LA_FIP10 AS LA_FIP10#647, properties#628.OBJECTID AS OBJECTID#648L, properties#628.POP_2010 AS POP_2010#649L, properties#628.PUMA10 AS PUMA10#650, properties#628.SPA_2012 AS SPA_2012#651L, properties#628.SPA_NAME AS SPA_NAME#652, properties#628.SUP_DIST AS SUP_DIST#653, properties#628.SUP_LABEL AS SUP_LABEL#654, properties#628.ShapeSTArea AS ShapeSTArea#655, properties#628.ShapeSTLength AS ShapeSTLength#656, ... 2 more fields]
#       +- Project [features#624.geometry AS geometry#627, features#624.properties AS properties#628, features#624.type AS type#629]
#          +- Project [features#624]
#             +- Generate explode(features#616), false, [features#624]
#                +- Relation [crs#615,features#616,name#617,type#618] geojson
#
# == Analyzed Logical Plan ==
# latitude: double, longitude: double, geom: geometry, COMM: string, unified_geometry: geometry
# Join Inner,  **org.apache.spark.sql.sedona_sql.expressions.ST_Within**
# :- Project [latitude#877, longitude#878,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#882]
# :  +- Project [LAT#847 AS latitude#877, LON#848 AS longitude#878]
# :     +- Relation [DR_NO#821,Date Rptd#822,DATE OCC#823,TIME OCC#824,AREA #825,AREA NAME#826,Rpt Dist No#827,Part 1-2#828,Crm Cd#829,Crm Cd Desc#830,Mocodes#831,Vict Age#832,Vict Sex#833,Vict Descent#834,Premis Cd#835,Premis Desc#836,Weapon Used Cd#837,Weapon Desc#838,Status#839,Status Desc#840,Crm Cd 1#841,Crm Cd 2#842,Crm Cd 3#843,Crm Cd 4#844,... 4 more fields] csv
# +- Aggregate [COMM#640], [COMM#640, st_union_aggr(geometry#627, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@228b9d6f, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, Some(ST_Union_Aggr)) AS unified_geometry#787]
#    +- Project [properties#628.BG10 AS BG10#633, properties#628.BG10FIP10 AS BG10FIP10#634, properties#628.BG12 AS BG12#635, properties#628.CB10 AS CB10#636, properties#628.CEN_FIP13 AS CEN_FIP13#637, properties#628.CITY AS CITY#638, properties#628.CITYCOM AS CITYCOM#639, properties#628.COMM AS COMM#640, properties#628.CT10 AS CT10#641, properties#628.CT12 AS CT12#642, properties#628.CTCB10 AS CTCB10#643, properties#628.HD_2012 AS HD_2012#644L, properties#628.HD_NAME AS HD_NAME#645, properties#628.HOUSING10 AS HOUSING10#646L, properties#628.LA_FIP10 AS LA_FIP10#647, properties#628.OBJECTID AS OBJECTID#648L, properties#628.POP_2010 AS POP_2010#649L, properties#628.PUMA10 AS PUMA10#650, properties#628.SPA_2012 AS SPA_2012#651L, properties#628.SPA_NAME AS SPA_NAME#652, properties#628.SUP_DIST AS SUP_DIST#653, properties#628.SUP_LABEL AS SUP_LABEL#654, properties#628.ShapeSTArea AS ShapeSTArea#655, properties#628.ShapeSTLength AS ShapeSTLength#656, ... 2 more fields]
#       +- Project [features#624.geometry AS geometry#627, features#624.properties AS properties#628, features#624.type AS type#629]
#          +- Project [features#624]
#             +- Generate explode(features#616), false, [features#624]
#                +- Relation [crs#615,features#616,name#617,type#618] geojson
#
# == Optimized Logical Plan ==
# Join Inner,  **org.apache.spark.sql.sedona_sql.expressions.ST_Within**
# :- Project [LAT#847 AS latitude#877, LON#848 AS longitude#878,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#882]
# :  +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
# :     +- Relation [DR_NO#821,Date Rptd#822,DATE OCC#823,TIME OCC#824,AREA #825,AREA NAME#826,Rpt Dist No#827,Part 1-2#828,Crm Cd#829,Crm Cd Desc#830,Mocodes#831,Vict Age#832,Vict Sex#833,Vict Descent#834,Premis Cd#835,Premis Desc#836,Weapon Used Cd#837,Weapon Desc#838,Status#839,Status Desc#840,Crm Cd 1#841,Crm Cd 2#842,Crm Cd 3#843,Crm Cd 4#844,... 4 more fields] csv
# +- Filter isnotnull(unified_geometry#787)
#    +- Aggregate [COMM#640], [COMM#640, st_union_aggr(geometry#627, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@228b9d6f, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, Some(ST_Union_Aggr)) AS unified_geometry#787]
#       +- Project [features#624.properties.COMM AS COMM#640, features#624.geometry AS geometry#627]
#          +- Generate explode(features#616), [0], false, [features#624]
#             +- Project [features#616]
#                +- Filter ((size(features#616, true) > 0) AND isnotnull(features#616))
#                   +- Relation [crs#615,features#616,name#617,type#618] geojson
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- RangeJoin geom#882: geometry, unified_geometry#787: geometry, WITHIN
#    :- Project [LAT#847 AS latitude#877, LON#848 AS longitude#878,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#882]
#    :  +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#    :     +- FileScan csv [LAT#847,LON#848] Batched: false, DataFilters: [isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_D..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<LAT:double,LON:double>
#    +- Filter isnotnull(unified_geometry#787)
#       +- ObjectHashAggregate(keys=[COMM#640], functions=[st_union_aggr(geometry#627, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@228b9d6f, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, Some(ST_Union_Aggr))], output=[COMM#640, unified_geometry#787])
#          +- Exchange hashpartitioning(COMM#640, 1000), ENSURE_REQUIREMENTS, [plan_id=2292]
#             +- ObjectHashAggregate(keys=[COMM#640], functions=[partial_st_union_aggr(geometry#627, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@228b9d6f, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, Some(ST_Union_Aggr))], output=[COMM#640, buf#897])
#                +- Project [features#624.properties.COMM AS COMM#640, features#624.geometry AS geometry#627]
#                   +- Generate explode(features#616), false, [features#624]
#                      +- Filter ((size(features#616, true) > 0) AND isnotnull(features#616))
#                         +- FileScan geojson [features#616] Batched: false, DataFilters: [(size(features#616, true) > 0), isnotnull(features#616)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Block..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:...
#
# == Parsed Logical Plan ==
# 'Join UsingJoin(LeftOuter, [COMM])
# :- Project [COMM#640, count#907L, total_population#937L, total_housing#967L]
# :  +- Join Inner, (COMM#640 = COMM#1057)
# :     :- Project [COMM#640, count#907L, total_population#937L]
# :     :  +- Join Inner, (COMM#640 = COMM#1024)
# :     :     :- Aggregate [COMM#640], [COMM#640, count(1) AS count#907L]
# :     :     :  +- Join Inner,  **org.apache.spark.sql.sedona_sql.expressions.ST_Within**
# :     :     :     :- Project [latitude#877, longitude#878,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#882]
# :     :     :     :  +- Project [LAT#847 AS latitude#877, LON#848 AS longitude#878]
# :     :     :     :     +- Relation [DR_NO#821,Date Rptd#822,DATE OCC#823,TIME OCC#824,AREA #825,AREA NAME#826,Rpt Dist No#827,Part 1-2#828,Crm Cd#829,Crm Cd Desc#830,Mocodes#831,Vict Age#832,Vict Sex#833,Vict Descent#834,Premis Cd#835,Premis Desc#836,Weapon Used Cd#837,Weapon Desc#838,Status#839,Status Desc#840,Crm Cd 1#841,Crm Cd 2#842,Crm Cd 3#843,Crm Cd 4#844,... 4 more fields] csv
# :     :     :     +- Aggregate [COMM#640], [COMM#640, st_union_aggr(geometry#627, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@228b9d6f, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, Some(ST_Union_Aggr)) AS unified_geometry#787]
# :     :     :        +- Project [properties#628.BG10 AS BG10#633, properties#628.BG10FIP10 AS BG10FIP10#634, properties#628.BG12 AS BG12#635, properties#628.CB10 AS CB10#636, properties#628.CEN_FIP13 AS CEN_FIP13#637, properties#628.CITY AS CITY#638, properties#628.CITYCOM AS CITYCOM#639, properties#628.COMM AS COMM#640, properties#628.CT10 AS CT10#641, properties#628.CT12 AS CT12#642, properties#628.CTCB10 AS CTCB10#643, properties#628.HD_2012 AS HD_2012#644L, properties#628.HD_NAME AS HD_NAME#645, properties#628.HOUSING10 AS HOUSING10#646L, properties#628.LA_FIP10 AS LA_FIP10#647, properties#628.OBJECTID AS OBJECTID#648L, properties#628.POP_2010 AS POP_2010#649L, properties#628.PUMA10 AS PUMA10#650, properties#628.SPA_2012 AS SPA_2012#651L, properties#628.SPA_NAME AS SPA_NAME#652, properties#628.SUP_DIST AS SUP_DIST#653, properties#628.SUP_LABEL AS SUP_LABEL#654, properties#628.ShapeSTArea AS ShapeSTArea#655, properties#628.ShapeSTLength AS ShapeSTLength#656, ... 2 more fields]
# :     :     :           +- Project [features#624.geometry AS geometry#627, features#624.properties AS properties#628, features#624.type AS type#629]
# :     :     :              +- Project [features#624]
# :     :     :                 +- Generate explode(features#616), false, [features#624]
# :     :     :                    +- Relation [crs#615,features#616,name#617,type#618] geojson
# :     :     +- Aggregate [COMM#1024], [COMM#1024, sum(POP_2010#1033L) AS total_population#937L]
# :     :        +- Project [properties#628.BG10 AS BG10#1017, properties#628.BG10FIP10 AS BG10FIP10#1018, properties#628.BG12 AS BG12#1019, properties#628.CB10 AS CB10#1020, properties#628.CEN_FIP13 AS CEN_FIP13#1021, properties#628.CITY AS CITY#1022, properties#628.CITYCOM AS CITYCOM#1023, properties#628.COMM AS COMM#1024, properties#628.CT10 AS CT10#1025, properties#628.CT12 AS CT12#1026, properties#628.CTCB10 AS CTCB10#1027, properties#628.HD_2012 AS HD_2012#1028L, properties#628.HD_NAME AS HD_NAME#1029, properties#628.HOUSING10 AS HOUSING10#1030L, properties#628.LA_FIP10 AS LA_FIP10#1031, properties#628.OBJECTID AS OBJECTID#1032L, properties#628.POP_2010 AS POP_2010#1033L, properties#628.PUMA10 AS PUMA10#1034, properties#628.SPA_2012 AS SPA_2012#1035L, properties#628.SPA_NAME AS SPA_NAME#1036, properties#628.SUP_DIST AS SUP_DIST#1037, properties#628.SUP_LABEL AS SUP_LABEL#1038, properties#628.ShapeSTArea AS ShapeSTArea#1039, properties#628.ShapeSTLength AS ShapeSTLength#1040, ... 2 more fields]
# :     :           +- Project [features#624.geometry AS geometry#627, features#624.properties AS properties#628, features#624.type AS type#629]
# :     :              +- Project [features#624]
# :     :                 +- Generate explode(features#1014), false, [features#624]
# :     :                    +- Relation [crs#1013,features#1014,name#1015,type#1016] geojson
# :     +- Aggregate [COMM#1057], [COMM#1057, sum(HOUSING10#1063L) AS total_housing#967L]
# :        +- Project [properties#628.BG10 AS BG10#1050, properties#628.BG10FIP10 AS BG10FIP10#1051, properties#628.BG12 AS BG12#1052, properties#628.CB10 AS CB10#1053, properties#628.CEN_FIP13 AS CEN_FIP13#1054, properties#628.CITY AS CITY#1055, properties#628.CITYCOM AS CITYCOM#1056, properties#628.COMM AS COMM#1057, properties#628.CT10 AS CT10#1058, properties#628.CT12 AS CT12#1059, properties#628.CTCB10 AS CTCB10#1060, properties#628.HD_2012 AS HD_2012#1061L, properties#628.HD_NAME AS HD_NAME#1062, properties#628.HOUSING10 AS HOUSING10#1063L, properties#628.LA_FIP10 AS LA_FIP10#1064, properties#628.OBJECTID AS OBJECTID#1065L, properties#628.POP_2010 AS POP_2010#1066L, properties#628.PUMA10 AS PUMA10#1067, properties#628.SPA_2012 AS SPA_2012#1068L, properties#628.SPA_NAME AS SPA_NAME#1069, properties#628.SUP_DIST AS SUP_DIST#1070, properties#628.SUP_LABEL AS SUP_LABEL#1071, properties#628.ShapeSTArea AS ShapeSTArea#1072, properties#628.ShapeSTLength AS ShapeSTLength#1073, ... 2 more fields]
# :           +- Project [features#624.geometry AS geometry#627, features#624.properties AS properties#628, features#624.type AS type#629]
# :              +- Project [features#624]
# :                 +- Generate explode(features#1047), false, [features#624]
# :                    +- Relation [crs#1046,features#1047,name#1048,type#1049] geojson
# +- Aggregate [COMM#1000], [COMM#1000, round(avg(Estimated Median Income#994), 2) AS median_income#1010]
#    +- Project [Zip Code#988, Community#989, Estimated Median Income#994, regexp_replace(Community#989, Los Angeles \(|\), , 1) AS COMM#1000]
#       +- Project [Zip Code#988, Community#989, cast(regexp_replace(trim(Estimated Median Income#990, None), [$,], , 1) as float) AS Estimated Median Income#994]
#          +- Relation [Zip Code#988,Community#989,Estimated Median Income#990] csv
#
# == Analyzed Logical Plan ==
# COMM: string, count: bigint, total_population: bigint, total_housing: bigint, median_income: double
# Project [COMM#640, count#907L, total_population#937L, total_housing#967L, median_income#1010]
# +- Join LeftOuter, (COMM#640 = COMM#1000)
#    :- Project [COMM#640, count#907L, total_population#937L, total_housing#967L]
#    :  +- Join Inner, (COMM#640 = COMM#1057)
#    :     :- Project [COMM#640, count#907L, total_population#937L]
#    :     :  +- Join Inner, (COMM#640 = COMM#1024)
#    :     :     :- Aggregate [COMM#640], [COMM#640, count(1) AS count#907L]
#    :     :     :  +- Join Inner,  **org.apache.spark.sql.sedona_sql.expressions.ST_Within**
#    :     :     :     :- Project [latitude#877, longitude#878,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#882]
#    :     :     :     :  +- Project [LAT#847 AS latitude#877, LON#848 AS longitude#878]
#    :     :     :     :     +- Relation [DR_NO#821,Date Rptd#822,DATE OCC#823,TIME OCC#824,AREA #825,AREA NAME#826,Rpt Dist No#827,Part 1-2#828,Crm Cd#829,Crm Cd Desc#830,Mocodes#831,Vict Age#832,Vict Sex#833,Vict Descent#834,Premis Cd#835,Premis Desc#836,Weapon Used Cd#837,Weapon Desc#838,Status#839,Status Desc#840,Crm Cd 1#841,Crm Cd 2#842,Crm Cd 3#843,Crm Cd 4#844,... 4 more fields] csv
#    :     :     :     +- Aggregate [COMM#640], [COMM#640, st_union_aggr(geometry#627, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@228b9d6f, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, Some(ST_Union_Aggr)) AS unified_geometry#787]
#    :     :     :        +- Project [properties#628.BG10 AS BG10#633, properties#628.BG10FIP10 AS BG10FIP10#634, properties#628.BG12 AS BG12#635, properties#628.CB10 AS CB10#636, properties#628.CEN_FIP13 AS CEN_FIP13#637, properties#628.CITY AS CITY#638, properties#628.CITYCOM AS CITYCOM#639, properties#628.COMM AS COMM#640, properties#628.CT10 AS CT10#641, properties#628.CT12 AS CT12#642, properties#628.CTCB10 AS CTCB10#643, properties#628.HD_2012 AS HD_2012#644L, properties#628.HD_NAME AS HD_NAME#645, properties#628.HOUSING10 AS HOUSING10#646L, properties#628.LA_FIP10 AS LA_FIP10#647, properties#628.OBJECTID AS OBJECTID#648L, properties#628.POP_2010 AS POP_2010#649L, properties#628.PUMA10 AS PUMA10#650, properties#628.SPA_2012 AS SPA_2012#651L, properties#628.SPA_NAME AS SPA_NAME#652, properties#628.SUP_DIST AS SUP_DIST#653, properties#628.SUP_LABEL AS SUP_LABEL#654, properties#628.ShapeSTArea AS ShapeSTArea#655, properties#628.ShapeSTLength AS ShapeSTLength#656, ... 2 more fields]
#    :     :     :           +- Project [features#624.geometry AS geometry#627, features#624.properties AS properties#628, features#624.type AS type#629]
#    :     :     :              +- Project [features#624]
#    :     :     :                 +- Generate explode(features#616), false, [features#624]
#    :     :     :                    +- Relation [crs#615,features#616,name#617,type#618] geojson
#    :     :     +- Aggregate [COMM#1024], [COMM#1024, sum(POP_2010#1033L) AS total_population#937L]
#    :     :        +- Project [properties#628.BG10 AS BG10#1017, properties#628.BG10FIP10 AS BG10FIP10#1018, properties#628.BG12 AS BG12#1019, properties#628.CB10 AS CB10#1020, properties#628.CEN_FIP13 AS CEN_FIP13#1021, properties#628.CITY AS CITY#1022, properties#628.CITYCOM AS CITYCOM#1023, properties#628.COMM AS COMM#1024, properties#628.CT10 AS CT10#1025, properties#628.CT12 AS CT12#1026, properties#628.CTCB10 AS CTCB10#1027, properties#628.HD_2012 AS HD_2012#1028L, properties#628.HD_NAME AS HD_NAME#1029, properties#628.HOUSING10 AS HOUSING10#1030L, properties#628.LA_FIP10 AS LA_FIP10#1031, properties#628.OBJECTID AS OBJECTID#1032L, properties#628.POP_2010 AS POP_2010#1033L, properties#628.PUMA10 AS PUMA10#1034, properties#628.SPA_2012 AS SPA_2012#1035L, properties#628.SPA_NAME AS SPA_NAME#1036, properties#628.SUP_DIST AS SUP_DIST#1037, properties#628.SUP_LABEL AS SUP_LABEL#1038, properties#628.ShapeSTArea AS ShapeSTArea#1039, properties#628.ShapeSTLength AS ShapeSTLength#1040, ... 2 more fields]
#    :     :           +- Project [features#624.geometry AS geometry#627, features#624.properties AS properties#628, features#624.type AS type#629]
#    :     :              +- Project [features#624]
#    :     :                 +- Generate explode(features#1014), false, [features#624]
#    :     :                    +- Relation [crs#1013,features#1014,name#1015,type#1016] geojson
#    :     +- Aggregate [COMM#1057], [COMM#1057, sum(HOUSING10#1063L) AS total_housing#967L]
#    :        +- Project [properties#628.BG10 AS BG10#1050, properties#628.BG10FIP10 AS BG10FIP10#1051, properties#628.BG12 AS BG12#1052, properties#628.CB10 AS CB10#1053, properties#628.CEN_FIP13 AS CEN_FIP13#1054, properties#628.CITY AS CITY#1055, properties#628.CITYCOM AS CITYCOM#1056, properties#628.COMM AS COMM#1057, properties#628.CT10 AS CT10#1058, properties#628.CT12 AS CT12#1059, properties#628.CTCB10 AS CTCB10#1060, properties#628.HD_2012 AS HD_2012#1061L, properties#628.HD_NAME AS HD_NAME#1062, properties#628.HOUSING10 AS HOUSING10#1063L, properties#628.LA_FIP10 AS LA_FIP10#1064, properties#628.OBJECTID AS OBJECTID#1065L, properties#628.POP_2010 AS POP_2010#1066L, properties#628.PUMA10 AS PUMA10#1067, properties#628.SPA_2012 AS SPA_2012#1068L, properties#628.SPA_NAME AS SPA_NAME#1069, properties#628.SUP_DIST AS SUP_DIST#1070, properties#628.SUP_LABEL AS SUP_LABEL#1071, properties#628.ShapeSTArea AS ShapeSTArea#1072, properties#628.ShapeSTLength AS ShapeSTLength#1073, ... 2 more fields]
#    :           +- Project [features#624.geometry AS geometry#627, features#624.properties AS properties#628, features#624.type AS type#629]
#    :              +- Project [features#624]
#    :                 +- Generate explode(features#1047), false, [features#624]
#    :                    +- Relation [crs#1046,features#1047,name#1048,type#1049] geojson
#    +- Aggregate [COMM#1000], [COMM#1000, round(avg(Estimated Median Income#994), 2) AS median_income#1010]
#       +- Project [Zip Code#988, Community#989, Estimated Median Income#994, regexp_replace(Community#989, Los Angeles \(|\), , 1) AS COMM#1000]
#          +- Project [Zip Code#988, Community#989, cast(regexp_replace(trim(Estimated Median Income#990, None), [$,], , 1) as float) AS Estimated Median Income#994]
#             +- Relation [Zip Code#988,Community#989,Estimated Median Income#990] csv
#
# == Optimized Logical Plan ==
# Project [COMM#640, count#907L, total_population#937L, total_housing#967L, median_income#1010]
# +- Join LeftOuter, (COMM#640 = COMM#1000)
#    :- Project [COMM#640, count#907L, total_population#937L, total_housing#967L]
#    :  +- Join Inner, (COMM#640 = COMM#1057)
#    :     :- Project [COMM#640, count#907L, total_population#937L]
#    :     :  +- Join Inner, (COMM#640 = COMM#1024)
#    :     :     :- Aggregate [COMM#640], [COMM#640, count(1) AS count#907L]
#    :     :     :  +- Project [COMM#640]
#    :     :     :     +- Join Inner,  **org.apache.spark.sql.sedona_sql.expressions.ST_Within**
#    :     :     :        :- Project [ **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#882]
#    :     :     :        :  +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#    :     :     :        :     +- Relation [DR_NO#821,Date Rptd#822,DATE OCC#823,TIME OCC#824,AREA #825,AREA NAME#826,Rpt Dist No#827,Part 1-2#828,Crm Cd#829,Crm Cd Desc#830,Mocodes#831,Vict Age#832,Vict Sex#833,Vict Descent#834,Premis Cd#835,Premis Desc#836,Weapon Used Cd#837,Weapon Desc#838,Status#839,Status Desc#840,Crm Cd 1#841,Crm Cd 2#842,Crm Cd 3#843,Crm Cd 4#844,... 4 more fields] csv
#    :     :     :        +- Filter isnotnull(unified_geometry#787)
#    :     :     :           +- Aggregate [COMM#640], [COMM#640, st_union_aggr(geometry#627, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@228b9d6f, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, Some(ST_Union_Aggr)) AS unified_geometry#787]
#    :     :     :              +- Project [features#624.properties.COMM AS COMM#640, features#624.geometry AS geometry#627]
#    :     :     :                 +- Filter ((isnotnull(features#624.properties.COMM) AND bloomfilter#1086 of [COMM#1024] filtering [features#624.properties.COMM]) AND bloomfilter#1085 of [COMM#1057] filtering [features#624.properties.COMM])
#    :     :     :                    :  :- Aggregate [COMM#1024], [COMM#1024, sum(POP_2010#1033L) AS total_population#937L]
#    :     :     :                    :  :  +- Project [features#624.properties.COMM AS COMM#1024, features#624.properties.POP_2010 AS POP_2010#1033L]
#    :     :     :                    :  :     +- Filter isnotnull(features#624.properties.COMM)
#    :     :     :                    :  :        +- Generate explode(features#1014), [0], false, [features#624]
#    :     :     :                    :  :           +- Project [features#1014]
#    :     :     :                    :  :              +- Filter ((size(features#1014, true) > 0) AND isnotnull(features#1014))
#    :     :     :                    :  :                 +- Relation [crs#1013,features#1014,name#1015,type#1016] geojson
#    :     :     :                    :  +- Aggregate [COMM#1057], [COMM#1057, sum(HOUSING10#1063L) AS total_housing#967L]
#    :     :     :                    :     +- Project [features#624.properties.COMM AS COMM#1057, features#624.properties.HOUSING10 AS HOUSING10#1063L]
#    :     :     :                    :        +- Filter isnotnull(features#624.properties.COMM)
#    :     :     :                    :           +- Generate explode(features#1047), [0], false, [features#624]
#    :     :     :                    :              +- Project [features#1047]
#    :     :     :                    :                 +- Filter ((size(features#1047, true) > 0) AND isnotnull(features#1047))
#    :     :     :                    :                    +- Relation [crs#1046,features#1047,name#1048,type#1049] geojson
#    :     :     :                    +- Generate explode(features#616), [0], false, [features#624]
#    :     :     :                       +- Project [features#616]
#    :     :     :                          +- Filter ((size(features#616, true) > 0) AND isnotnull(features#616))
#    :     :     :                             +- Relation [crs#615,features#616,name#617,type#618] geojson
#    :     :     +- Aggregate [COMM#1024], [COMM#1024, sum(POP_2010#1033L) AS total_population#937L]
#    :     :        +- Project [features#624.properties.COMM AS COMM#1024, features#624.properties.POP_2010 AS POP_2010#1033L]
#    :     :           +- Filter isnotnull(features#624.properties.COMM)
#    :     :              +- Generate explode(features#1014), [0], false, [features#624]
#    :     :                 +- Project [features#1014]
#    :     :                    +- Filter ((size(features#1014, true) > 0) AND isnotnull(features#1014))
#    :     :                       +- Relation [crs#1013,features#1014,name#1015,type#1016] geojson
#    :     +- Aggregate [COMM#1057], [COMM#1057, sum(HOUSING10#1063L) AS total_housing#967L]
#    :        +- Project [features#624.properties.COMM AS COMM#1057, features#624.properties.HOUSING10 AS HOUSING10#1063L]
#    :           +- Filter isnotnull(features#624.properties.COMM)
#    :              +- Generate explode(features#1047), [0], false, [features#624]
#    :                 +- Project [features#1047]
#    :                    +- Filter ((size(features#1047, true) > 0) AND isnotnull(features#1047))
#    :                       +- Relation [crs#1046,features#1047,name#1048,type#1049] geojson
#    +- Aggregate [COMM#1000], [COMM#1000, round(avg(Estimated Median Income#994), 2) AS median_income#1010]
#       +- Project [cast(regexp_replace(trim(Estimated Median Income#990, None), [$,], , 1) as float) AS Estimated Median Income#994, regexp_replace(Community#989, Los Angeles \(|\), , 1) AS COMM#1000]
#          +- Filter isnotnull(regexp_replace(Community#989, Los Angeles \(|\), , 1))
#             +- Relation [Zip Code#988,Community#989,Estimated Median Income#990] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [COMM#640, count#907L, total_population#937L, total_housing#967L, median_income#1010]
#    +- BroadcastHashJoin [COMM#640], [COMM#1000], LeftOuter, BuildRight, false
#       :- Project [COMM#640, count#907L, total_population#937L, total_housing#967L]
#       :  +- SortMergeJoin [COMM#640], [COMM#1057], Inner
#       :     :- Project [COMM#640, count#907L, total_population#937L]
#       :     :  +- SortMergeJoin [COMM#640], [COMM#1024], Inner
#       :     :     :- Sort [COMM#640 ASC NULLS FIRST], false, 0
#       :     :     :  +- HashAggregate(keys=[COMM#640], functions=[count(1)], output=[COMM#640, count#907L], schema specialized)
#       :     :     :     +- Exchange hashpartitioning(COMM#640, 1000), ENSURE_REQUIREMENTS, [plan_id=2677]
#       :     :     :        +- HashAggregate(keys=[COMM#640], functions=[partial_count(1)], output=[COMM#640, count#1088L], schema specialized)
#       :     :     :           +- Project [COMM#640]
#       :     :     :              +- RangeJoin geom#882: geometry, unified_geometry#787: geometry, WITHIN
#       :     :     :                 :- Project [ **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#882]
#       :     :     :                 :  +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#       :     :     :                 :     +- FileScan csv [LAT#847,LON#848] Batched: false, DataFilters: [isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_D..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<LAT:double,LON:double>
#       :     :     :                 +- Filter isnotnull(unified_geometry#787)
#       :     :     :                    +- ObjectHashAggregate(keys=[COMM#640], functions=[st_union_aggr(geometry#627, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@228b9d6f, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, Some(ST_Union_Aggr))], output=[COMM#640, unified_geometry#787])
#       :     :     :                       +- Exchange hashpartitioning(COMM#640, 1000), ENSURE_REQUIREMENTS, [plan_id=2671]
#       :     :     :                          +- ObjectHashAggregate(keys=[COMM#640], functions=[partial_st_union_aggr(geometry#627, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@228b9d6f, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, Some(ST_Union_Aggr))], output=[COMM#640, buf#897])
#       :     :     :                             +- Project [features#624.properties.COMM AS COMM#640, features#624.geometry AS geometry#627]
#       :     :     :                                +- Filter isnotnull(features#624.properties.COMM)
#       :     :     :                                   +- Generate explode(features#616), false, [features#624]
#       :     :     :                                      +- Filter ((size(features#616, true) > 0) AND isnotnull(features#616))
#       :     :     :                                         +- FileScan geojson [features#616] Batched: false, DataFilters: [(size(features#616, true) > 0), isnotnull(features#616)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Block..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:...
#       :     :     +- Sort [COMM#1024 ASC NULLS FIRST], false, 0
#       :     :        +- HashAggregate(keys=[COMM#1024], functions=[sum(POP_2010#1033L)], output=[COMM#1024, total_population#937L], schema specialized)
#       :     :           +- Exchange hashpartitioning(COMM#1024, 1000), ENSURE_REQUIREMENTS, [plan_id=2629]
#       :     :              +- HashAggregate(keys=[COMM#1024], functions=[partial_sum(POP_2010#1033L)], output=[COMM#1024, sum#1090L], schema specialized)
#       :     :                 +- Project [features#624.properties.COMM AS COMM#1024, features#624.properties.POP_2010 AS POP_2010#1033L]
#       :     :                    +- Filter isnotnull(features#624.properties.COMM)
#       :     :                       +- Generate explode(features#1014), false, [features#624]
#       :     :                          +- Filter ((size(features#1014, true) > 0) AND isnotnull(features#1014))
#       :     :                             +- FileScan geojson [features#1014] Batched: false, DataFilters: [(size(features#1014, true) > 0), isnotnull(features#1014)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Block..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:...
#       :     +- Sort [COMM#1057 ASC NULLS FIRST], false, 0
#       :        +- HashAggregate(keys=[COMM#1057], functions=[sum(HOUSING10#1063L)], output=[COMM#1057, total_housing#967L], schema specialized)
#       :           +- Exchange hashpartitioning(COMM#1057, 1000), ENSURE_REQUIREMENTS, [plan_id=2637]
#       :              +- HashAggregate(keys=[COMM#1057], functions=[partial_sum(HOUSING10#1063L)], output=[COMM#1057, sum#1092L], schema specialized)
#       :                 +- Project [features#624.properties.COMM AS COMM#1057, features#624.properties.HOUSING10 AS HOUSING10#1063L]
#       :                    +- Filter isnotnull(features#624.properties.COMM)
#       :                       +- Generate explode(features#1047), false, [features#624]
#       :                          +- Filter ((size(features#1047, true) > 0) AND isnotnull(features#1047))
#       :                             +- FileScan geojson [features#1047] Batched: false, DataFilters: [(size(features#1047, true) > 0), isnotnull(features#1047)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Block..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:...
#       +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=2647]
#          +- HashAggregate(keys=[COMM#1000], functions=[avg(Estimated Median Income#994)], output=[COMM#1000, median_income#1010], schema specialized)
#             +- Exchange hashpartitioning(COMM#1000, 1000), ENSURE_REQUIREMENTS, [plan_id=2644]
#                +- HashAggregate(keys=[COMM#1000], functions=[partial_avg(Estimated Median Income#994)], output=[COMM#1000, sum#1095, count#1096L], schema specialized)
#                   +- Project [cast(regexp_replace(trim(Estimated Median Income#990, None), [$,], , 1) as float) AS Estimated Median Income#994, regexp_replace(Community#989, Los Angeles \(|\), , 1) AS COMM#1000]
#                      +- Filter isnotnull(regexp_replace(Community#989, Los Angeles \(|\), , 1))
#                         +- FileScan csv [Community#989,Estimated Median Income#990] Batched: false, DataFilters: [isnotnull(regexp_replace(Community#989, Los Angeles \(|\), , 1))], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<Community:string,Estimated Median Income:string>
#
# +------------------------------+-----+-----------------+-------------+------------------------+-------------+----------------+
# |COMM                          |count|crimes_per_person|median_income|median_income_per_person|total_housing|total_population|
# +------------------------------+-----+-----------------+-------------+------------------------+-------------+----------------+
# |                              |37   |0.00143          |NULL         |NULL                    |8292         |25919           |
# |Acton                         |1    |0.00012          |86944.0      |32868.55                |3075         |8134            |
# |Adams-Normandie               |4040 |0.51517          |NULL         |NULL                    |2424         |7842            |
# |Agoura Hills                  |6    |0.00030          |NULL         |NULL                    |7585         |20330           |
# |Alhambra                      |83   |0.00100          |54360.5      |20225.96                |30915        |83089           |
# |Alsace                        |4334 |0.36954          |NULL         |NULL                    |3439         |11728           |
# |Altadena                      |1    |0.00002          |86310.0      |32175.83                |15947        |42777           |
# |Anaverde                      |4    |0.00268          |NULL         |NULL                    |528          |1491            |
# |Angeles National Forest       |155  |0.10923          |NULL         |NULL                    |567          |1419            |
# |Angelino Heights              |954  |0.40152          |NULL         |NULL                    |957          |2376            |
# |Arcadia                       |2    |0.00003          |77771.5      |28460.14                |23396        |63933           |
# |Arleta                        |10876|0.33082          |NULL         |NULL                    |7662         |32876           |
# |Athens Village                |9    |0.00180          |NULL         |NULL                    |1228         |4994            |
# |Athens-Westmont               |454  |0.01119          |NULL         |NULL                    |13279        |40582           |
# |Atwater Village               |6624 |0.46975          |NULL         |NULL                    |5691         |14101           |
# |Avalon                        |6    |0.00161          |NULL         |NULL                    |2266         |3728            |
# |Azusa                         |3    |0.00005          |NULL         |NULL                    |16981        |61882           |
# |Baldwin Hills                 |24751|0.86430          |NULL         |NULL                    |13353        |28637           |
# |Bel Air                       |2380 |0.28810          |NULL         |NULL                    |3456         |8261            |
# |Bell Gardens                  |9    |0.00021          |NULL         |NULL                    |9986         |42072           |
# |Bellflower                    |3    |0.00004          |48823.0      |15865.44                |24897        |76616           |
# |Beverly Crest                 |3252 |0.26675          |NULL         |NULL                    |5393         |12191           |
# |Beverly Hills                 |1091 |0.03199          |102447.0     |49239.68                |16394        |34109           |
# |Beverlywood                   |4388 |0.35344          |NULL         |NULL                    |5497         |12415           |
# |Boyle Heights                 |40453|0.48959          |27622.0      |7203.44                 |21548        |82627           |
# |Brentwood                     |10144|0.34620          |NULL         |NULL                    |15437        |29301           |
# |Brookside                     |374  |0.60225          |NULL         |NULL                    |242          |621             |
# |Burbank                       |830  |0.00803          |62016.75     |26590.87                |44309        |103340          |
# |Cadillac-Corning              |2893 |0.43406          |NULL         |NULL                    |2215         |6665            |
# |Calabasas                     |11   |0.00048          |NULL         |NULL                    |8878         |23058           |
# |Canoga Park                   |37017|0.62801          |45793.0      |16202.31                |20855        |58943           |
# |Carson                        |302  |0.00329          |74351.5      |21261.12                |26226        |91714           |
# |Carthay                       |7621 |0.57888          |NULL         |NULL                    |8303         |13165           |
# |Castaic                       |2    |0.00007          |NULL         |NULL                    |6657         |27831           |
# |Central                       |16830|0.47513          |NULL         |NULL                    |8174         |35422           |
# |Century City                  |6493 |0.54609          |97891.0      |54494.58                |6619         |11890           |
# |Century Palms/Cove            |26714|0.87039          |NULL         |NULL                    |8009         |30692           |
# |Cerritos                      |5    |0.00010          |89720.0      |28954.95                |16003        |49587           |
# |Chatsworth                    |16803|0.48498          |80593.0      |30548.9                 |13133        |34647           |
# |Cheviot Hills                 |3540 |0.39233          |NULL         |NULL                    |4020         |9023            |
# |Chinatown                     |5722 |0.74534          |NULL         |NULL                    |3418         |7677            |
# |Claremont                     |6    |0.00017          |89161.0      |31040.38                |12306        |35348           |
# |Cloverdale/Cochran            |6900 |0.49173          |NULL         |NULL                    |4984         |14032           |
# |Commerce                      |4    |0.00031          |NULL         |NULL                    |3470         |12823           |
# |Compton                       |5    |0.00005          |NULL         |NULL                    |24523        |96455           |
# |Country Club Park             |6761 |0.46912          |NULL         |NULL                    |5352         |14412           |
# |Covina                        |1    |0.00002          |63711.5      |20933.39                |21041        |64039           |
# |Covina (Charter Oak)          |1    |0.00008          |NULL         |NULL                    |3982         |12306           |
# |Crenshaw District             |9582 |0.72823          |NULL         |NULL                    |5350         |13158           |
# |Crestview                     |4811 |0.44608          |NULL         |NULL                    |4932         |10785           |
# |Culver City                   |1014 |0.02608          |75913.5      |34148.68                |17491        |38883           |
# |Del Aire                      |1    |0.00024          |NULL         |NULL                    |1595         |4127            |
# |Del Rey                       |10537|0.37809          |NULL         |NULL                    |12287        |27869           |
# |Del Sur                       |1    |0.00041          |NULL         |NULL                    |934          |2417            |
# |Desert View Highlands         |1    |0.00042          |NULL         |NULL                    |764          |2360            |
# |Diamond Bar                   |1    |0.00002          |90522.0      |30076.76                |18455        |55544           |
# |Downey                        |34   |0.00030          |64316.0      |20485.58                |35601        |111772          |
# |Downtown                      |56899|2.40618          |NULL         |NULL                    |17103        |23647           |
# |Duarte                        |4    |0.00015          |NULL         |NULL                    |8228         |25911           |
# |Eagle Rock                    |14089|0.37388          |63358.0      |22205.48                |13207        |37683           |
# |East Hollywood                |16019|0.56417          |33912.0      |12792.54                |10711        |28394           |
# |East Los Angeles              |340  |0.00269          |37916.0      |9651.66                 |32199        |126492          |
# |East Pasadena                 |1    |0.00013          |NULL         |NULL                    |2674         |7435            |
# |Echo Park                     |6678 |0.48902          |NULL         |NULL                    |5903         |13656           |
# |El Monte                      |4    |0.00004          |38070.0      |9754.99                 |29112        |113613          |
# |El Segundo                    |90   |0.00540          |85727.0      |38143.21                |7410         |16654           |
# |El Sereno                     |14214|0.35706          |NULL         |NULL                    |11872        |39808           |
# |Elysian Park                  |3722 |0.70666          |NULL         |NULL                    |1993         |5267            |
# |Elysian Valley                |3996 |0.40985          |NULL         |NULL                    |3204         |9750            |
# |Encino                        |19819|0.46799          |98562.0      |44129.36                |18961        |42349           |
# |Exposition                    |3191 |0.98548          |NULL         |NULL                    |1041         |3238            |
# |Exposition Park               |33611|0.79811          |NULL         |NULL                    |11541        |42113           |
# |Faircrest Heights             |2972 |0.86320          |NULL         |NULL                    |1356         |3443            |
# |Figueroa Park Square          |5297 |0.64028          |NULL         |NULL                    |2570         |8273            |
# |Florence-Firestone            |36608|0.34226          |NULL         |NULL                    |25913        |106961          |
# |Franklin Canyon               |1    |0.09091          |NULL         |NULL                    |3            |11              |
# |Gardena                       |353  |0.00600          |49137.67     |17934.76                |21472        |58829           |
# |Glassell Park                 |10723|0.36090          |NULL         |NULL                    |10174        |29712           |
# |Glendale                      |92   |0.00048          |66520.33     |26462.89                |76269        |191719          |
# |Glendora                      |1    |0.00002          |76010.0      |26962.0                 |17982        |50694           |
# |Gramercy Place                |7947 |0.76701          |NULL         |NULL                    |3941         |10361           |
# |Granada Hills                 |22968|0.41630          |79680.0      |27230.6                 |18855        |55172           |
# |Green Meadows                 |16451|0.82998          |NULL         |NULL                    |5204         |19821           |
# |Hancock Park                  |9259 |0.59517          |NULL         |NULL                    |6653         |15557           |
# |Harbor City                   |12024|0.44588          |52294.0      |19581.89                |10098        |26967           |
# |Harbor Gateway                |18411|0.45870          |NULL         |NULL                    |12399        |40137           |
# |Harbor Pines                  |772  |0.35267          |NULL         |NULL                    |804          |2189            |
# |Harvard Heights               |9157 |0.54020          |NULL         |NULL                    |5199         |16951           |
# |Harvard Park                  |29869|0.81952          |NULL         |NULL                    |10822        |36447           |
# |Hawthorne                     |4    |0.00005          |NULL         |NULL                    |30487        |86781           |
# |Hermosa Beach                 |18   |0.00092          |111187.0     |57924.86                |10162        |19506           |
# |Hidden Hills                  |3    |0.00162          |NULL         |NULL                    |626          |1856            |
# |Highland Park                 |16440|0.36130          |49630.0      |16888.73                |15484        |45502           |
# |Historic Filipinotown         |7682 |0.57868          |NULL         |NULL                    |4248         |13275           |
# |Hollywood                     |63825|1.02264          |47025.0      |26943.01                |35759        |62412           |
# |Hollywood Hills               |15567|0.55806          |NULL         |NULL                    |17180        |27895           |
# |Huntington Park               |6    |0.00010          |NULL         |NULL                    |15151        |58114           |
# |Hyde Park                     |21496|0.76928          |NULL         |NULL                    |10347        |27943           |
# |Inglewood                     |868  |0.00791          |46038.5      |16131.71                |38429        |109673          |
# |Irwindale                     |2    |0.00141          |NULL         |NULL                    |390          |1422            |
# |Jefferson Park                |3728 |0.48975          |NULL         |NULL                    |2306         |7612            |
# |Kagel/Lopez Canyons           |1    |0.00076          |NULL         |NULL                    |528          |1318            |
# |Koreatown                     |24390|0.50523          |NULL         |NULL                    |19863        |48275           |
# |La Cañada Flintridge          |1    |0.00005          |156933.0     |54949.03                |7089         |20246           |
# |La Habra Heights              |1    |0.00017          |67797.0      |23704.06                |2095         |5992            |
# |La Mirada                     |1    |0.00002          |78373.0      |24374.17                |15092        |48527           |
# |La Puente                     |14   |0.00035          |NULL         |NULL                    |9761         |39816           |
# |La Rambla                     |202  |0.09931          |NULL         |NULL                    |663          |2034            |
# |La Verne                      |1    |0.00003          |75635.0      |28099.05                |12343        |33224           |
# ...
# |Long Beach                    |108  |0.00023          |57920.33     |22057.51                |176576       |463667          |
# |Longwood                      |2109 |0.50095          |NULL         |NULL                    |1474         |4210            |
# |Los Feliz                     |12549|0.61042          |NULL         |NULL                    |11626        |20558           |
# |Lynwood                       |24   |0.00034          |43231.0      |9465.69                 |15277        |69772           |
# |Malibu                        |1    |0.00008          |123681.0     |67136.92                |6864         |12645           |
# |Manchester Square             |6207 |0.75264          |NULL         |NULL                    |3064         |8247            |
# |Mandeville Canyon             |626  |0.19363          |NULL         |NULL                    |1342         |3233            |
# |Manhattan Beach               |32   |0.00091          |143527.0     |60985.19                |14929        |35135           |
# |Mar Vista                     |13005|0.33239          |NULL         |NULL                    |18038        |39126           |
# |Marina Peninsula              |1737 |0.40051          |NULL         |NULL                    |2815         |4337            |
# |Marina del Rey                |541  |0.06102          |NULL         |NULL                    |6742         |8866            |
# |Maywood                       |1    |0.00004          |NULL         |NULL                    |6766         |27395           |
# |Melrose                       |43800|0.59571          |NULL         |NULL                    |33102        |73526           |
# |Mid-city                      |7349 |0.51252          |NULL         |NULL                    |6692         |14339           |
# |Miracle Mile                  |8738 |0.54408          |NULL         |NULL                    |9694         |16060           |
# |Mission Hills                 |10723|0.47109          |61728.0      |17507.95                |6456         |22762           |
# |Monrovia                      |1    |0.00002          |70307.0      |27258.17                |15681        |40446           |
# |Montebello                    |6    |0.00010          |45898.0      |14516.99                |19768        |62500           |
# |Monterey Park                 |5    |0.00008          |53341.5      |18453.44                |20850        |60269           |
# |Mt. Washington                |7982 |0.34664          |NULL         |NULL                    |7606         |23027           |
# |Newhall                       |2    |0.00966          |NULL         |NULL                    |84           |207             |
# |North Hills                   |26592|0.47170          |55956.0      |16087.54                |16208        |56375           |
# |North Hollywood               |79751|0.56019          |42254.0      |15556.31                |52413        |142364          |
# |Northridge                    |34744|0.53668          |61366.0      |22114.47                |23330        |64739           |
# |Norwalk                       |5    |0.00005          |59756.0      |15899.04                |28083        |105549          |
# |Pacific Palisades             |6413 |0.31066          |NULL         |NULL                    |9048         |20643           |
# |Pacoima                       |29059|0.39436          |NULL         |NULL                    |16533        |73687           |
# |Palisades Highlands           |495  |0.12914          |NULL         |NULL                    |1545         |3833            |
# |Palmdale                      |17   |0.00011          |54132.0      |16503.67                |46786        |153458          |
# |Palms                         |13801|0.33290          |58004.0      |29692.47                |21222        |41457           |
# |Palos Verdes Estates          |1    |0.00007          |NULL         |NULL                    |5283         |13438           |
# |Panorama City                 |32448|0.46684          |37190.0      |10164.71                |18997        |69505           |
# |Paramount                     |31   |0.00057          |45792.0      |12333.82                |14571        |54098           |
# |Park La Brea                  |8006 |0.67951          |NULL         |NULL                    |6173         |11782           |
# |Pasadena                      |30   |0.00022          |76752.5      |33333.0                 |59551        |137122          |
# |Pico Rivera                   |2    |0.00003          |55758.0      |15156.23                |17109        |62942           |
# |Pico-Union                    |20070|0.50417          |NULL         |NULL                    |13452        |39808           |
# |Playa Del Rey                 |1661 |0.52597          |NULL         |NULL                    |1752         |3158            |
# |Playa Vista                   |4332 |0.48532          |104367.0     |56217.4                 |4808         |8926            |
# |Pomona                        |7    |0.00005          |47705.0      |12920.91                |40900        |151006          |
# |Porter Ranch                  |8958 |0.28520          |NULL         |NULL                    |11080        |31409           |
# |Rancho Dominguez              |2    |0.00077          |NULL         |NULL                    |1033         |2597            |
# |Rancho Palos Verdes           |131  |0.00315          |NULL         |NULL                    |16179        |41643           |
# |Rancho Park                   |5444 |0.86481          |NULL         |NULL                    |2794         |6295            |
# |Redondo Beach                 |5    |0.00007          |NULL         |NULL                    |30609        |66748           |
# |Regent Square                 |1552 |0.57867          |NULL         |NULL                    |907          |2682            |
# |Reseda                        |29736|0.41404          |51206.0      |16841.46                |23621        |71819           |
# |Reseda Ranch                  |2453 |0.54560          |NULL         |NULL                    |1237         |4496            |
# |Reynier Village               |1993 |0.48788          |NULL         |NULL                    |1722         |4085            |
# |Rosemead                      |1    |0.00002          |46729.0      |12867.77                |14805        |53764           |
# |Rosewood/East Gardena         |93   |0.07990          |NULL         |NULL                    |354          |1164            |
# |Rosewood/West Rancho Dominguez|1    |0.00031          |NULL         |NULL                    |863          |3217            |
# |Rowland Heights               |2    |0.00004          |NULL         |NULL                    |15169        |49042           |
# |San Dimas                     |2    |0.00006          |77742.0      |29134.32                |12506        |33371           |
# |San Fernando                  |76   |0.00321          |NULL         |NULL                    |6291         |23645           |
# |San Pedro                     |40057|0.54374          |NULL         |NULL                    |30148        |73669           |
# |Santa Clarita                 |33   |0.00019          |NULL         |NULL                    |62055        |176320          |
# |Santa Fe Springs              |1    |0.00006          |54674.0      |16769.88                |4976         |16223           |
# |Santa Monica                  |612  |0.00682          |93137.33     |52841.76                |50912        |89736           |
# |Santa Monica Mountains        |4    |0.00021          |NULL         |NULL                    |7081         |19222           |
# |Shadow Hills                  |1802 |0.40449          |NULL         |NULL                    |1662         |4455            |
# |Sherman Oaks                  |44678|0.54858          |NULL         |NULL                    |41461        |81443           |
# |Signal Hill                   |2    |0.00018          |65935.0      |26269.85                |4389         |11016           |
# |Silverlake                    |20659|0.50016          |NULL         |NULL                    |19455        |41305           |
# |South Carthay                 |4838 |0.47934          |NULL         |NULL                    |5519         |10093           |
# |South Gate                    |1    |0.00001          |43552.0      |11146.83                |24160        |94396           |
# |South Park                    |21733|0.61386          |NULL         |NULL                    |8612         |35404           |
# |South Pasadena                |19   |0.00074          |79089.0      |34322.63                |11118        |25619           |
# |St Elmo Village               |2418 |0.54252          |NULL         |NULL                    |1256         |4457            |
# |Studio City                   |13307|0.64276          |NULL         |NULL                    |10740        |20703           |
# |Sun Valley                    |23533|0.45912          |NULL         |NULL                    |13712        |51257           |
# |Sunland                       |7073 |0.35999          |NULL         |NULL                    |7452         |19648           |
# |Sycamore Square               |528  |0.83150          |NULL         |NULL                    |320          |635             |
# |Sylmar                        |29218|0.37743          |NULL         |NULL                    |20977        |77413           |
# |Tarzana                       |15288|0.51502          |68078.0      |29197.58                |12731        |29684           |
# |Temple-Beaudry                |17831|0.48765          |NULL         |NULL                    |13609        |36565           |
# |Thai Town                     |3124 |0.33412          |NULL         |NULL                    |4866         |9350            |
# |Toluca Lake                   |4278 |0.54159          |NULL         |NULL                    |4515         |7899            |
# |Toluca Terrace                |219  |0.16833          |NULL         |NULL                    |541          |1301            |
# |Toluca Woods                  |901  |0.49370          |NULL         |NULL                    |845          |1825            |
# |Torrance                      |409  |0.00281          |74483.75     |29896.85                |58377        |145438          |
# |Tujunga                       |8740 |0.32622          |58020.0      |22084.5                 |10198        |26792           |
# |Twin Lakes/Oat Mountain       |6    |0.00415          |NULL         |NULL                    |601          |1446            |
# |Universal City                |93   |NULL             |NULL         |NULL                    |0            |0               |
# |University Hills              |732  |0.23334          |NULL         |NULL                    |812          |3137            |
# |University Park               |16064|0.64665          |NULL         |NULL                    |7338         |24842           |
# |Valley Glen                   |11034|0.39050          |39013.0      |14592.6                 |10569        |28256           |
# |Valley Village                |10392|0.46197          |NULL         |NULL                    |11723        |22495           |
# |Van Nuys                      |55606|0.64644          |45667.0      |15486.19                |29170        |86019           |
# |Venice                        |27424|0.84058          |80111.0      |46048.17                |18753        |32625           |
# |Vermont Knolls                |14222|0.85274          |NULL         |NULL                    |5564         |16678           |
# |Vermont Square                |4049 |0.57473          |NULL         |NULL                    |1953         |7045            |
# |Vermont Vista                 |34973|0.93137          |NULL         |NULL                    |10499        |37550           |
# |Vernon                        |567  |5.06250          |NULL         |NULL                    |29           |112             |
# |Vernon Central                |25359|0.51996          |NULL         |NULL                    |11009        |48771           |
# |Victoria Park                 |3883 |0.48641          |NULL         |NULL                    |2683         |7983            |
# |View Heights                  |1562 |0.47958          |NULL         |NULL                    |1303         |3257            |
# |View Park/Windsor Hills       |1145 |0.10339          |NULL         |NULL                    |4777         |11075           |
# |Walnut                        |2    |0.00007          |NULL         |NULL                    |8753         |29172           |
# |Walnut Park                   |2    |0.00013          |NULL         |NULL                    |3744         |15966           |
# |Watts                         |28268|0.71281          |NULL         |NULL                    |9802         |39657           |
# |Wellington Square             |3205 |0.69583          |NULL         |NULL                    |1729         |4606            |
# |West Adams                    |14159|0.53344          |38330.0      |13535.29                |9373         |26543           |
# |West Carson                   |358  |0.01650          |NULL         |NULL                    |7426         |21699           |
# |West Chatsworth               |6    |0.50000          |NULL         |NULL                    |4            |12              |
# |West Covina                   |2    |0.00002          |69635.0      |21465.18                |32705        |106098          |
# |West Hills                    |13065|0.34083          |NULL         |NULL                    |13437        |38333           |
# |West Hollywood                |495  |0.01439          |NULL         |NULL                    |24588        |34399           |
# |West LA                       |1252 |1.78348          |NULL         |NULL                    |65           |702             |
# |West Los Angeles              |17283|0.50587          |NULL         |NULL                    |18977        |34165           |
# |West Rancho Dominguez         |1    |0.00078          |NULL         |NULL                    |365          |1288            |
# |West Vernon                   |38753|0.77044          |NULL         |NULL                    |14516        |50300           |
# |Westchester                   |36689|0.76408          |NULL         |NULL                    |21090        |48017           |
# |Westhills                     |7    |0.00895          |NULL         |NULL                    |306          |782             |
# |Westlake                      |35451|0.64883          |27890.0      |10972.65                |21496        |54638           |
# |Westlake Village              |1    |0.00012          |104382.5     |42712.26                |3384         |8270            |
# |Westwood                      |13765|0.26713          |57202.0      |24362.11                |21946        |51529           |
# |Whittier                      |2    |0.00002          |68485.5      |23787.91                |30869        |88872           |
# |Wholesale District            |50902|1.36995          |NULL         |NULL                    |11358        |37156           |
# |Willowbrook                   |354  |0.01061          |NULL         |NULL                    |8855         |33373           |
# |Wilmington                    |27252|0.51884          |41569.0      |11169.22                |14113        |52525           |
# |Wilshire Center               |27418|0.57972          |NULL         |NULL                    |19835        |47295           |
# |Winnetka                      |22947|0.48002          |61529.0      |19695.36                |15302        |47804           |
# |Woodland Hills                |31767|0.50167          |86456.5      |38205.9                 |27983        |63323           |
# +------------------------------+-----+-----------------+-------------+------------------------+-------------+----------------+
